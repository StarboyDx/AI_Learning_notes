# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame({
    'id' : list('abcdef'),
    'name' : ['Alice', 'Bob', 'Charlie', 'David', 'Esther', 'Fanny'],
    'age' : [34, 36, 30, 29, 32, 36]
})

# %%
df1
# Out:
#   id     name  age
# 0  a    Alice   34
# 1  b      Bob   36
# 2  c  Charlie   30
# 3  d    David   29
# 4  e   Esther   32
# 5  f    Fanny   36

# %%
# Output the third row of the transposed data
df2 = df1.T

# %%
df2
# Out:
#           0    1        2      3       4      5
# id        a    b        c      d       e      f
# name  Alice  Bob  Charlie  David  Esther  Fanny
# age      34   36       30     29      32     36

# %%
df2[2]
# Out:
# id            c
# name    Charlie
# age          30
# Name: 2, dtype: object

# %%
df2.loc['age']
# return Series
# Out:
# 0    34
# 1    36
# 2    30
# 3    29
# 4    32
# 5    36
# Name: age, dtype: object

# %%
df2.loc[['age']] #DataFrame
# Out:
#       0   1   2   3   4   5
# age  34  36  30  29  32  36

# %%
df2.iloc[[2]]
# Out:
#       0   1   2   3   4   5
# age  34  36  30  29  32  36

# %%
df2[2:]
# Out:
#       0   1   2   3   4   5
# age  34  36  30  29  32  36

# %%
df1
# Out:
#   id     name  age
# 0  a    Alice   34
# 1  b      Bob   36
# 2  c  Charlie   30
# 3  d    David   29
# 4  e   Esther   32
# 5  f    Fanny   36

# %%
df1.iloc[6] = ['g', 'john', 19]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df1.iloc[6] = ['g', 'john', 19]
#
# File D:\anaconda3\Lib\site-packages\pandas\core\indexing.py:908, in _LocationIndexer.__setitem__(self, key, value)
#     906     key = self._check_deprecated_callable_usage(key, maybe_callable)
#     907 indexer = self._get_setitem_indexer(key)
# --> 908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
#     911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File D:\anaconda3\Lib\site-packages\pandas\core\indexing.py:1646, in _iLocIndexer._has_valid_setitem_indexer(self, indexer)
#    1644 elif is_integer(i):
#    1645     if i >= len(ax):
# -> 1646         raise IndexError("iloc cannot enlarge its target object")
#    1647 elif isinstance(i, dict):
# ...

# %%
df1.loc[6] = ['g', 'john', 19]

# %%
df1
# Out:
#   id     name  age
# 0  a    Alice   34
# 1  b      Bob   36
# 2  c  Charlie   30
# 3  d    David   29
# 4  e   Esther   32
# 5  f    Fanny   36
# 6  g     john   19

# %%
# delete the third row (del can't delete a row)
del df1.loc[2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 # delete the third row (del can't delete a row)
# ----> 2 del df1.loc[2]
#
# AttributeError: __delitem__

# %%
df3 = df1.T

# %%
df3
# Out:
#           0    1        2      3       4      5     6
# id        a    b        c      d       e      f     g
# name  Alice  Bob  Charlie  David  Esther  Fanny  john
# age      34   36       30     29      32     36    19

# %%
df3[2]
# Out:
# id            c
# name    Charlie
# age          30
# Name: 2, dtype: object

# %%
del df3[2]

# %%
df3
# Out:
#           0    1      3       4      5     6
# id        a    b      d       e      f     g
# name  Alice  Bob  David  Esther  Fanny  john
# age      34   36     29      32     36    19

# %%
df4 = df3.T
df4
# Out:
#   id    name age
# 0  a   Alice  34
# 1  b     Bob  36
# 3  d   David  29
# 4  e  Esther  32
# 5  f   Fanny  36
# 6  g    john  19

# %%
# Find the ages of Bob and David.
df1.loc[[1,3]].age
# Out:
# 1    36
# 3    29
# Name: age, dtype: int64
