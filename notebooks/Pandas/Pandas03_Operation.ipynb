# %%
import numpy as np
import pandas as pd

# %%
dates = ['2025-09-01', '2025-09-02', '2025-09-03', '2025-09-04', '2025-09-05', '2025-09-06', '2025-09-07']

# %%
datesI = pd.to_datetime(dates)

# %%
df1 = pd.DataFrame(np.random.randint(80, 100, (7,5)),
                   index = datesI,
                   columns = list('ABCDE'))

# %%
df1
# Out:
#              A   B   C   D   E
# 2025-09-01  91  84  95  88  85
# 2025-09-02  84  81  83  80  95
# 2025-09-03  81  88  81  89  93
# 2025-09-04  91  93  96  82  91
# 2025-09-05  99  89  89  90  89
# 2025-09-06  98  82  84  84  93
# 2025-09-07  96  89  85  82  90

# %%
# ?pd.DataFrame.rank
# Out:
# Signature:
# pd.DataFrame.rank(
#     self,
#     axis: 'Axis' = 0,
#     method: "Literal['average', 'min', 'max', 'first', 'dense']" = 'average',
#     numeric_only: 'bool_t' = False,
#     na_option: "Literal['keep', 'top', 'bottom']" = 'keep',
#     ascending: 'bool_t' = True,
#     pct: 'bool_t' = False,
# ) -> 'Self'
# Docstring:
# Compute numerical data ranks (1 through n) along axis.
#
# By default, equal values are assigned a rank that is the average of the
# ranks of those values.
#
# Parameters
# ----------
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Index to direct ranking.
#     For `Series` this parameter is unused and defaults to 0.
# method : {'average', 'min', 'max', 'first', 'dense'}, default 'average'
#     How to rank the group of records that have the same value (i.e. ties):
#
#     * average: average rank of the group
#     * min: lowest rank in the group
#     * max: highest rank in the group
# ...

# %%
# Rank stocks in ascending order.
df1.rank(axis = 0) #Default
# Out:
#               A    B    C    D    E
# 2025-09-01  3.5  3.0  6.0  5.0  1.0
# 2025-09-02  2.0  1.0  2.0  1.0  7.0
# 2025-09-03  1.0  4.0  1.0  6.0  5.5
# 2025-09-04  3.5  7.0  7.0  2.5  4.0
# 2025-09-05  7.0  5.5  5.0  7.0  2.0
# 2025-09-06  6.0  2.0  3.0  4.0  5.5
# 2025-09-07  5.0  5.5  4.0  2.5  3.0

# %%
df1.rank(axis=1, ascending=False)
# Out:
#               A    B    C    D    E
# 2025-09-01  2.0  5.0  1.0  3.0  4.0
# 2025-09-02  2.0  4.0  3.0  5.0  1.0
# 2025-09-03  4.5  3.0  4.5  2.0  1.0
# 2025-09-04  3.5  2.0  1.0  5.0  3.5
# 2025-09-05  1.0  4.0  4.0  2.0  4.0
# 2025-09-06  1.0  5.0  3.5  3.5  2.0
# 2025-09-07  1.0  3.0  4.0  5.0  2.0

# %% [markdown]
# # Operations in pandas
# ## operations on objects and numerical values

# %%
S1 = pd.Series([1,2,3], index = list('abc'))

# %%
S1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
S1 + 3
#Element-wise operations.
# Out:
# a    4
# b    5
# c    6
# dtype: int64

# %%
df2 = pd.DataFrame(np.arange(1,13).reshape((3,4)),
                   index = list('ABC'),
                   columns = list('abcd')
                  )

# %%
df2
# Out:
#    a   b   c   d
# A  1   2   3   4
# B  5   6   7   8
# C  9  10  11  12

# %%
df2 * 3
# Out:
#     a   b   c   d
# A   3   6   9  12
# B  15  18  21  24
# C  27  30  33  36

# %% [markdown]
# # Operations between objects
# ## Series operations: index alignment.

# %%
S1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
S2 = pd.Series([2,3,6], index = list('bcd'))

# %%
S2
# Out:
# b    2
# c    3
# d    6
# dtype: int64

# %%
S1+S2
# Out:
# a    NaN
# b    4.0
# c    6.0
# d    NaN
# dtype: float64

# %% [markdown]
# # Operations between Series and DataFrame: alignment of Series index with DataFrame columns.

# %%
df1
# Out:
#              A   B   C   D   E
# 2025-09-01  91  84  95  88  85
# 2025-09-02  84  81  83  80  95
# 2025-09-03  81  88  81  89  93
# 2025-09-04  91  93  96  82  91
# 2025-09-05  99  89  89  90  89
# 2025-09-06  98  82  84  84  93
# 2025-09-07  96  89  85  82  90

# %%
df2
# Out:
#    a   b   c   d
# A  1   2   3   4
# B  5   6   7   8
# C  9  10  11  12

# %%
df2 + S1
# S1 transpose→duplicate→alignment
# Out:
#       a     b     c   d
# A   2.0   4.0   6.0 NaN
# B   6.0   8.0  10.0 NaN
# C  10.0  12.0  14.0 NaN

# %% [markdown]
# ## Operations between DataFrames: alignment based on both index and columns.

# %%
df2
# Out:
#    a   b   c   d
# A  1   2   3   4
# B  5   6   7   8
# C  9  10  11  12

# %%
df3 = pd.DataFrame(np.arange(1,13).reshape((4,3)),
                   index = list('BCDE'),
                   columns = list('cde'))

# %%
df3
# Out:
#     c   d   e
# B   1   2   3
# C   4   5   6
# D   7   8   9
# E  10  11  12

# %%
df2 * df3
#Intersection ; Overlap part
# Out:
#     a   b     c     d   e
# A NaN NaN   NaN   NaN NaN
# B NaN NaN   7.0  16.0 NaN
# C NaN NaN  44.0  60.0 NaN
# D NaN NaN   NaN   NaN NaN
# E NaN NaN   NaN   NaN NaN

# %% [markdown]
# ## Perform operations using methods

# %%
df2.add(df3)
# Out:
#     a   b     c     d   e
# A NaN NaN   NaN   NaN NaN
# B NaN NaN   8.0  10.0 NaN
# C NaN NaN  15.0  17.0 NaN
# D NaN NaN   NaN   NaN NaN
# E NaN NaN   NaN   NaN NaN

# %%
df2 + df3
# Out:
#     a   b     c     d   e
# A NaN NaN   NaN   NaN NaN
# B NaN NaN   8.0  10.0 NaN
# C NaN NaN  15.0  17.0 NaN
# D NaN NaN   NaN   NaN NaN
# E NaN NaN   NaN   NaN NaN

# %%
df2.add(df3, fill_value = 0)
# Fill first, then calculate.
# Out:
#      a     b     c     d     e
# A  1.0   2.0   3.0   4.0   NaN
# B  5.0   6.0   8.0  10.0   3.0
# C  9.0  10.0  15.0  17.0   6.0
# D  NaN   NaN   7.0   8.0   9.0
# E  NaN   NaN  10.0  11.0  12.0

# %% [markdown]
# # The Index of Pandas
# ## Features of the index

# %%
df_dict = {
    '上海' : {2019:200000,2020:300000},
    '北京' : {2020:210000,2021:250000}
}

# %%
df_dict
# Out:
# {'上海': {2019: 200000, 2020: 300000}, '北京': {2020: 210000, 2021: 250000}}

# %%
df1 = pd.DataFrame(df_dict)

# %%
df1
# Out:
#             上海        北京
# 2019  200000.0       NaN
# 2020  300000.0  210000.0
# 2021       NaN  250000.0

# %%
df1.index
# Out:
# Index([2019, 2020, 2021], dtype='int64')

# %%
df1.columns
# Out:
# Index(['上海', '北京'], dtype='object')

# %%
df1.values
# Out:
# array([[200000.,     nan],
#        [300000., 210000.],
#        [    nan, 250000.]])

# %%
df1.index[0]
# Out:
# 2019

# %%
df1.inde[0] = 2018
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df1.inde[0] = 2018
#
# File D:\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'inde'

# %%
df1.columns[1] = '广州'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df1.columns[1] = '广州'
#
# File D:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5371, in Index.__setitem__(self, key, value)
#    5369 @final
#    5370 def __setitem__(self, key, value) -> None:
# -> 5371     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
df1.columns[1]
# Out:
# '北京'

# %%
# Adding an index.
df1.insert(0, column = '广州', value=[120000,150000,180000])

# %%
df1
# Out:
#           广州        上海        北京
# 2019  120000  200000.0       NaN
# 2020  150000  300000.0  210000.0
# 2021  180000       NaN  250000.0

# %%
df1.insert(-1, column = '编号', value=[1,2,3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df1.insert(-1, column = '编号', value=[1,2,3])
#
# File D:\anaconda3\Lib\site-packages\pandas\core\frame.py:5172, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    5169     value = value.iloc[:, 0]
#    5171 value, refs = self._sanitize_column(value)
# -> 5172 self._mgr.insert(loc, column, value, refs=refs)
#
# File D:\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1376, in BlockManager.insert(self, loc, item, value, refs)
#    1373 else:
#    1374     value = ensure_block_shape(value, ndim=self.ndim)
# -> 1376 bp = BlockPlacement(slice(loc, loc + 1))
#    1377 block = new_block_2d(values=value, placement=bp, refs=refs)
#    1379 if not len(self.blocks):
#    1380     # Fastpath
#
# File internals.pyx:51, in pandas._libs.internals.BlockPlacement.__cinit__()
#
# ...

# %%
len(df1.columns)
# Out:
# 3

# %%
df1.insert(len(df1.columns), column = '编号', value = [1,2,3])

# %%
df1
# Out:
#           广州        上海        北京  编号
# 2019  120000  200000.0       NaN   1
# 2020  150000  300000.0  210000.0   2
# 2021  180000       NaN  250000.0   3

# %%
df1.drop('上海', axis = 1)
# Out:
#           广州        北京  编号
# 2019  120000       NaN   1
# 2020  150000  210000.0   2
# 2021  180000  250000.0   3

# %%
df1
# Out:
#           广州        上海        北京  编号
# 2019  120000  200000.0       NaN   1
# 2020  150000  300000.0  210000.0   2
# 2021  180000       NaN  250000.0   3

# %%
df2 = df1.drop('上海', axis = 1)

# %%
df2
# Out:
#           广州        北京  编号
# 2019  120000       NaN   1
# 2020  150000  210000.0   2
# 2021  180000  250000.0   3

# %%
df4 = df1.copy()

# %%
df4.drop('上海', errors = 'ignore')
# Out:
#           广州        上海        北京  编号
# 2019  120000  200000.0       NaN   1
# 2020  150000  300000.0  210000.0   2
# 2021  180000       NaN  250000.0   3

# %%
#delete row
df4.drop(2020)
# Out:
#           广州        上海        北京  编号
# 2019  120000  200000.0       NaN   1
# 2021  180000       NaN  250000.0   3

# %%
df4.drop(index = [2019,2020])
# Out:
#           广州  上海        北京  编号
# 2021  180000 NaN  250000.0   3

# %%
df4.drop(columns = ['编号'])
# Out:
#           广州        上海        北京
# 2019  120000  200000.0       NaN
# 2020  150000  300000.0  210000.0
# 2021  180000       NaN  250000.0

# %% [markdown]
# ## Building a hierarchical index.

# %%
df5 = pd.DataFrame(
    np.arange(20).reshape(4,5),
    index = [
        ['one', 'one', 'two', 'two'], ['a', 'b', 'c', 'd']
    ],
    columns = [
        ['A', 'A', 'A', 'B', 'B'], [1,2,3,4,5]
    ])

# %%
df5
# Out:
#         A           B
#         1   2   3   4   5
# one a   0   1   2   3   4
#     b   5   6   7   8   9
# two c  10  11  12  13  14
#     d  15  16  17  18  19

# %%
df5.index
# Out:
# MultiIndex([('one', 'a'),
#             ('one', 'b'),
#             ('two', 'c'),
#             ('two', 'd')],
#            )

# %%
df1.index
# Out:
# Index([2019, 2020, 2021], dtype='int64')

# %%
df5.columns
# Out:
# MultiIndex([('A', 1),
#             ('A', 2),
#             ('A', 3),
#             ('B', 4),
#             ('B', 5)],
#            )

# %%
# ?pd.DataFrame.drop
# Out:
# Signature:
# pd.DataFrame.drop(
#     self,
#     labels: 'IndexLabel | None' = None,
#     *,
#     axis: 'Axis' = 0,
#     index: 'IndexLabel | None' = None,
#     columns: 'IndexLabel | None' = None,
#     level: 'Level | None' = None,
#     inplace: 'bool' = False,
#     errors: 'IgnoreRaise' = 'raise',
# ) -> 'DataFrame | None'
# Docstring:
# Drop specified labels from rows or columns.
#
# Remove rows or columns by specifying label names and corresponding
# axis, or by directly specifying index or column names. When using a
# multi-index, labels on different levels can be removed by specifying
# the level. See the :ref:`user guide <advanced.shown_levels>`
# for more information about the now unused levels.
#
# Parameters
# ----------
# labels : single label or list-like
#     Index or column labels to drop. A tuple will be used as a single
#     label and not treated as a list-like.
# axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
df5.drop(index = 'one', level = 0)
# Out:
#         A           B
#         1   2   3   4   5
# two c  10  11  12  13  14
#     d  15  16  17  18  19

# %%
df5.drop(index = 'one')
# Out:
#         A           B
#         1   2   3   4   5
# two c  10  11  12  13  14
#     d  15  16  17  18  19

# %%
df5.drop(index = 'b')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'b'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 df5.drop(index = 'b')
#
# ...

# %%
df5.drop(index = 'b', level = 1)
# Out:
#         A           B
#         1   2   3   4   5
# one a   0   1   2   3   4
# two c  10  11  12  13  14
#     d  15  16  17  18  19

# %%
df5.drop(columns = [2,5], level = 1)
# Out:
#         A       B
#         1   3   4
# one a   0   2   3
#     b   5   7   8
# two c  10  12  13
#     d  15  17  18

# %% [markdown]
# ## Creation of an index object

# %%
df6 = pd.DataFrame(np.random.randint(10,50,(3,6)),
                   index = pd.Index(('人参', '当归', '枸杞'), name = '药品'),
                   columns = [
                       ['A'] * 3 + ['B'] * 3,
                       [1,2,3,1,2,3]
                   ]
                  )

# %%
df6
# Out:
#      A           B
#      1   2   3   1   2   3
# 药品
# 人参  31  27  46  36  13  13
# 当归  39  35  39  38  25  19
# 枸杞  49  26  45  28  44  48

# %%
df6.columns.names = ['仓库', '编号']
df6
# Out:
# 仓库   A           B
# 编号   1   2   3   1   2   3
# 药品
# 人参  31  27  46  36  13  13
# 当归  39  35  39  38  25  19
# 枸杞  49  26  45  28  44  48

# %%
df6.index
# Out:
# Index(['人参', '当归', '枸杞'], dtype='object', name='药品')

# %%
df6.columns
# Out:
# MultiIndex([('A', 1),
#             ('A', 2),
#             ('A', 3),
#             ('B', 1),
#             ('B', 2),
#             ('B', 3)],
#            names=['仓库', '编号'])

# %%
df6.drop(columns=3,level='编号')
# Out:
# 仓库   A       B
# 编号   1   2   1   2
# 药品
# 人参  31  27  36  13
# 当归  39  35  38  25
# 枸杞  49  26  28  44

# %%
df6.to_excel('test.xlsx')
