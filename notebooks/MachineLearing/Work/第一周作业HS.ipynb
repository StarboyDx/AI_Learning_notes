# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv('../02数据预备_清洗及特征工程/data/titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 计算年龄均值
titanic['Age'].mean()
# Out:
# 29.69911764705882

# %%
# 计算年龄方差
titanic['Age'].var()
# Out:
# 211.0191247463081

# %%
# 计算年龄标准差
titanic['Age'].std()
# Out:
# 14.526497332334044

# %%
# 计算年龄最小值
titanic['Age'].min()
# Out:
# 0.42

# %%
# 计算年龄最大值
titanic['Age'].max()
# Out:
# 80.0

# %%
# 绘制年龄频率分布直方图
titanic.hist(column = 'Age', bins = 50)
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 得到Age平均值
age_mean = titanic['Age'].mean()
age_mean
# Out:
# 29.69911764705882

# %%
# 处理Age缺失值
titanic['Age'].fillna(age_mean, inplace = True)
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_31832\3558097833.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# 中心化转换
# 查看中心化后的结果
titanic['Age_centered'] = titanic['Age'] - titanic['Age'].mean() # 计算方法：Age - Age均值
titanic['Age_centered']
# Out:
# 0      -7.699118
# 1       8.300882
# 2      -3.699118
# 3       5.300882
# 4       5.300882
#          ...
# 886    -2.699118
# 887   -10.699118
# 888     0.000000
# 889    -3.699118
# 890     2.300882
# Name: Age_centered, Length: 891, dtype: float64

# %%
print(f'mean: {titanic['Age_centered'].mean():.6f}') # 验证
# Out:
# mean: 0.000000

# %%
#下面用sklearn快速实现
from sklearn.preprocessing import StandardScaler, MinMaxScaler #标准化 、 归一化

# %%
#age_series = titanic['Age'].fillna(age_mean, inplace = True)
#FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
#The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
age_series = titanic['Age'].fillna(age_mean)

# %%
# 计算年龄标准差
# age_normalized = (age_series - age_series.min()) / (age_series.max() - age_series.min()) #手动计算公式
# 年龄标准化转换
scaler = StandardScaler()
age_standardized_sk = scaler.fit_transform(age_series.values.reshape(-1, 1)).flatten()

# 查标准化后结果
age_standardized_sk
# Out:
# array([-0.5924806 ,  0.63878901, -0.2846632 ,  0.40792596,  0.40792596,
#         0.        ,  1.87005862, -2.13156761, -0.20770885, -1.20811541,
#        -1.97765891,  2.17787603, -0.7463893 ,  0.71574336, -1.20811541,
#         1.94701297, -2.13156761,  0.        ,  0.10010856,  0.        ,
#         0.40792596,  0.33097161, -1.13116105, -0.1307545 , -1.66984151,
#         0.63878901,  0.        , -0.82334365,  0.        ,  0.        ,
#         0.79269771,  0.        ,  0.        ,  2.79351083, -0.1307545 ,
#         0.94660642,  0.        , -0.66943495, -0.900298  , -1.20811541,
#         0.79269771, -0.20770885,  0.        , -2.05461326, -0.82334365,
#         0.        ,  0.        ,  0.        ,  0.        , -0.900298  ,
#        -1.74679586, -0.66943495,  1.48528687, -0.05380014,  2.71655648,
#         0.        , -0.66943495, -0.09227732, -1.90070456, -1.43897846,
#        -0.5924806 ,  0.63878901,  1.17746947, -1.97765891,  0.        ,
# ...

# %%
# 验证：标准化后均值≈0，标准差≈1
print(f"标准化后均值：{age_standardized_sk.mean():.6f}")
print(f"标准化后标准差：{age_standardized_sk.std():.6f}")
# Out:
# 标准化后均值：0.000000
# 标准化后标准差：1.000000

# %%
# Age最大值
titanic['Age'].max()
# Out:
# 80.0

# %%
# 归一化变换
# age_normalized = (age_series - age_series.min()) / (age_series.max() - age_series.min()) #公式
# 查看归一化变换结果
min_max_scaler = MinMaxScaler()
age_normalized_sk = min_max_scaler.fit_transform(age_series.values.reshape(-1, 1)).flatten()

age_normalized_sk
# Out:
# array([0.27117366, 0.4722292 , 0.32143755, 0.43453129, 0.43453129,
#        0.36792055, 0.67328474, 0.01985423, 0.33400352, 0.17064589,
#        0.04498618, 0.72354863, 0.24604172, 0.48479517, 0.17064589,
#        0.68585072, 0.01985423, 0.36792055, 0.3842674 , 0.36792055,
#        0.43453129, 0.42196532, 0.18321186, 0.34656949, 0.09525006,
#        0.4722292 , 0.36792055, 0.23347575, 0.36792055, 0.36792055,
#        0.49736115, 0.36792055, 0.36792055, 0.8240764 , 0.34656949,
#        0.52249309, 0.36792055, 0.25860769, 0.22090978, 0.17064589,
#        0.49736115, 0.33400352, 0.36792055, 0.03242021, 0.23347575,
#        0.36792055, 0.36792055, 0.36792055, 0.36792055, 0.22090978,
#        0.08268409, 0.25860769, 0.61045489, 0.35913546, 0.81151043,
#        0.36792055, 0.25860769, 0.35285248, 0.05755215, 0.13294798,
#        0.27117366, 0.4722292 , 0.560191  , 0.04498618, 0.36792055,
#        0.36792055, 0.35913546, 0.23347575, 0.2083438 , 0.32143755,
# ...

# %%
# 验证：归一化后最小值≈0，最大值≈1
print(f"归一化后最小值：{age_normalized_sk.min():.6f}")
print(f"归一化后最大值：{age_normalized_sk.max():.6f}")
# Out:
# 归一化后最小值：0.000000
# 归一化后最大值：1.000000

# %%
# 对数变换
import numpy as np
titanic['Age_log'] = np.log(titanic['Age'])
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_centered   Age_log
# 0      0         A/5 21171   7.2500   NaN        S     -7.699118  3.091042
# 1      0          PC 17599  71.2833   C85        C      8.300882  3.637586
# 2      0  STON/O2. 3101282   7.9250   NaN        S     -3.699118  3.258097
# ...
