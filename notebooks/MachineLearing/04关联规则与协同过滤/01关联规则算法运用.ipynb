# %%
# https://github.com/asaini/Apriori
# 使用该项目的实现验证概念

# %%
# %run D:/github/Apriori/apriori.py -f D:/github/Apriori/INTEGRATED-DATASET.csv -s 0.1 -c 0.3
# Out:
# item: ('Brooklyn', 'MBE') , 0.113
# item: ('New York', 'NON-MINORITY') , 0.118
# item: ('New York', 'NON-MINORITY', 'WBE') , 0.118
# item: ('Brooklyn',) , 0.152
# item: ('HISPANIC',) , 0.164
# item: ('MBE', 'HISPANIC') , 0.164
# item: ('MBE', 'WBE') , 0.169
# item: ('New York', 'MBE') , 0.170
# item: ('New York', 'WBE') , 0.175
# item: ('MBE', 'ASIAN') , 0.200
# item: ('ASIAN',) , 0.202
# item: ('New York',) , 0.295
# item: ('NON-MINORITY',) , 0.300
# item: ('NON-MINORITY', 'WBE') , 0.300
# item: ('BLACK',) , 0.301
# item: ('MBE', 'BLACK') , 0.301
# item: ('WBE',) , 0.477
# item: ('MBE',) , 0.671
#
# ------------------------ RULES:
# Rule: ('WBE',) ==> ('MBE',) , 0.354
# Rule: ('WBE',) ==> ('New York',) , 0.367
# Rule: ('NON-MINORITY',) ==> ('New York',) , 0.394
# Rule: ('NON-MINORITY',) ==> ('New York', 'WBE') , 0.394
# Rule: ('NON-MINORITY', 'WBE') ==> ('New York',) , 0.394
# Rule: ('New York',) ==> ('NON-MINORITY',) , 0.401
# ...
