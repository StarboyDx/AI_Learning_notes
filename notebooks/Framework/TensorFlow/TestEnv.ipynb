# %%
import tensorflow as tf

# # 防止tf一次占用全部显存
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#     try:
#         # 遍历所有识别到的 GPU，设置为按需增长模式
#         for gpu in gpus:
#             tf.config.experimental.set_memory_growth(gpu, True)
#         print(f" 成功开启 {len(gpus)} 个 GPU 的显存按需增长模式！")
#     except RuntimeError as e:
#         # 如果在程序运行中途才设置，会触发这个异常
#         print(" 显存设置失败：", e)
# else:
#     print(" 未检测到 GPU，将使用 CPU 运行。")

# 打印版本号
print("TensorFlow Version:", tf.__version__)

# 测试是否能正常做张量运算
hello = tf.constant('Hello, TensorFlow from Docker!')
print(hello.numpy())

# 查看能识别到的物理设备（CPU/GPU）
print("Available Devices:", tf.config.list_physical_devices())
# Out:
# 2026-03-19 19:51:55.124057: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-19 19:51:55.124209: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-19 19:51:55.192454: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# TensorFlow Version: 2.15.0
# b'Hello, TensorFlow from Docker!'
# Available Devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-03-19 19:51:58.527603: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
