# %%
#pip install pyecharts 安装这个包(anaconda navigator中没有)，可以做一些更强大的web中可交互的图表

# %%
import numpy as np
import pandas as pd
from pyecharts.charts import *
# 载入所有的图形元件
from pyecharts import options as opts
# 载入options（选项）

# %%
# 绘制柱状图
# 1. 准备数据
x = ['猪肉', '水果', '蔬菜', '海鲜']
y = [240, 179, 280, 199]

# 2. 构建图形元件
bar = Bar()

# 3. 向元件中添加数据
bar.add_xaxis(x)
bar.add_yaxis('销量', y)

# 4. 渲染输出
bar.render_notebook() # 不加_notebook在当前路径下生成一个html文件，加的话输出会比较慢（要下载）
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="512e3ad735574ad492d317a70367e931" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_512e3ad735574ad492d317a70367e931 = echarts.init(
#                     document.getElementById('512e3ad735574ad492d317a70367e931'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_512e3ad735574ad492d317a70367e931 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9500\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 240,
#                 179,
#                 280,
#                 199
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "valueAnimation": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u91cf"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "\u732a\u8089",
#                 "\u6c34\u679c",
#                 "\u852c\u83dc",
#                 "\u6d77\u9c9c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0
#         }
#     ]
# };
#                 chart_512e3ad735574ad492d317a70367e931.setOption(option_512e3ad735574ad492d317a70367e931);
#         });
#     </script>

# %%
# 链式调用
# 1. 准备数据
x = ['猪肉', '水果', '蔬菜', '海鲜']
y = [240, 179, 280, 199]

# 2.构建元件，同时传入数据
# Bar().add_xaxis(s).add_yaxis('销量', y).render_notebook()
bar = (
    Bar()
    .add_xaxis(x)
    .add_yaxis('销量', y)
    )

# 3. 渲染输出
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2ebfce5a501748e1afa1d9d856403292" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2ebfce5a501748e1afa1d9d856403292 = echarts.init(
#                     document.getElementById('2ebfce5a501748e1afa1d9d856403292'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_2ebfce5a501748e1afa1d9d856403292 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9500\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 240,
#                 179,
#                 280,
#                 199
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "valueAnimation": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u91cf"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "\u732a\u8089",
#                 "\u6c34\u679c",
#                 "\u852c\u83dc",
#                 "\u6d77\u9c9c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0
#         }
#     ]
# };
#                 chart_2ebfce5a501748e1afa1d9d856403292.setOption(option_2ebfce5a501748e1afa1d9d856403292);
#         });
#     </script>

# %% [markdown]
# # pyechart常见图形
# ## 折线图

# %%
# 1. 准备数据
x = ['2025-05-01','2025-05-02','2025-05-03','2025-05-04','2025-05-05','2025-05-06','2025-05-07']
y = [1500,1600,2000,2100,1900,1850,2000]
#y = np.random.randint(1000,2000,7) # pyecharts对numpy的数据数据类型支持不好（如这里int64），要转换成python数据类型（int）
#实在要这么做可以遍历numpy数组进行转换


# 2. 构建元件，传入数据
line = (
    Line()
    .add_xaxis(x)
    .add_yaxis('人数', y)
)

# 3. 渲染输出
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="394bbd59f4834872b0f3e9d217ae03dc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_394bbd59f4834872b0f3e9d217ae03dc = echarts.init(
#                     document.getElementById('394bbd59f4834872b0f3e9d217ae03dc'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_394bbd59f4834872b0f3e9d217ae03dc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u4eba\u6570",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "2025-05-01",
#                     1500
#                 ],
#                 [
#                     "2025-05-02",
#                     1600
#                 ],
#                 [
#                     "2025-05-03",
#                     2000
#                 ],
#                 [
#                     "2025-05-04",
#                     2100
#                 ],
#                 [
#                     "2025-05-05",
#                     1900
#                 ],
#                 [
#                     "2025-05-06",
#                     1850
#                 ],
#                 [
#                     "2025-05-07",
#                     2000
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4eba\u6570"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "2025-05-01",
#                 "2025-05-02",
#                 "2025-05-03",
#                 "2025-05-04",
#                 "2025-05-05",
#                 "2025-05-06",
#                 "2025-05-07"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0
#         }
#     ]
# };
#                 chart_394bbd59f4834872b0f3e9d217ae03dc.setOption(option_394bbd59f4834872b0f3e9d217ae03dc);
#         });
#     </script>

# %%
# 折线图的升级
# 1. 准备数据
x = ['2025-05-01','2025-05-02','2025-05-03','2025-05-04','2025-05-05','2025-05-06','2025-05-07']
y = [1500,1600,2000,2100,1900,1850,2000]
# tips: min_y = min(y) // 100 * 100 对百位取整

# 2. 构建元件，传入数据，同时进行选项的设置
# (链式调用)
line = (
    Line(init_opts = opts.InitOpts(width = '700px', height  = '350px')) #设置图像大小
    .add_xaxis(x)
    .add_yaxis('发送顾客人数', y)
    .set_global_opts(           #设置全局选项，括号里是参数
        title_opts = opts.TitleOpts(title = '五一期间运送旅客人数',
                                    pos_left = 'center'
                                    ), #title_opts是set_global_opts的第一个参数
        legend_opts = opts.LegendOpts(pos_left = 'right'), #图例放右侧
        yaxis_opts = opts.AxisOpts(min_ = min(y) - 100,  #最低刻度
                      max_ = max(y) + 200,  #最高刻度
                      max_interval = 100    #刻度之间的间距
        )
    )
)

# 3. 渲染输出
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4c0485b9494d4e569bd9fc8442b7f348" style="width:700px; height:350px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4c0485b9494d4e569bd9fc8442b7f348 = echarts.init(
#                     document.getElementById('4c0485b9494d4e569bd9fc8442b7f348'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_4c0485b9494d4e569bd9fc8442b7f348 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u53d1\u9001\u987e\u5ba2\u4eba\u6570",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "2025-05-01",
#                     1500
#                 ],
#                 [
#                     "2025-05-02",
#                     1600
#                 ],
#                 [
#                     "2025-05-03",
#                     2000
#                 ],
#                 [
#                     "2025-05-04",
#                     2100
#                 ],
#                 [
#                     "2025-05-05",
#                     1900
#                 ],
#                 [
#                     "2025-05-06",
#                     1850
#                 ],
#                 [
#                     "2025-05-07",
#                     2000
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u53d1\u9001\u987e\u5ba2\u4eba\u6570"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "right",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "2025-05-01",
#                 "2025-05-02",
#                 "2025-05-03",
#                 "2025-05-04",
#                 "2025-05-05",
#                 "2025-05-06",
#                 "2025-05-07"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 1400,
#             "max": 2300,
#             "minInterval": 0,
#             "maxInterval": 100,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u4e94\u4e00\u671f\u95f4\u8fd0\u9001\u65c5\u5ba2\u4eba\u6570",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_4c0485b9494d4e569bd9fc8442b7f348.setOption(option_4c0485b9494d4e569bd9fc8442b7f348);
#         });
#     </script>

# %% [markdown]
# ## 饼图/环形图

# %%
# 1. 准备数据
x = ['华为','小米','Oppo','Vivo','中兴']
y = [123,154,109,104,76]
# 包装数据，将数据打包成嵌套的容器
pie_data = [list(z) for z in zip(x,y)]
print(pie_data)

# 2. 构建元件，传入数据，设置选项
pie = (
    Pie()
    .add('',
        pie_data,
        radius = ['40%','70%'] # 内径, 外径
        )
    .set_global_opts(title_opts = opts.TitleOpts(title = '国产手机销量对比'))    
)

# 3. 渲染输出
pie.render_notebook()
# Out:
# [['华为', 123], ['小米', 154], ['Oppo', 109], ['Vivo', 104], ['中兴', 76]]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5a48b03f3743455dbb4f504cc5fc4cf0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5a48b03f3743455dbb4f504cc5fc4cf0 = echarts.init(
#                     document.getElementById('5a48b03f3743455dbb4f504cc5fc4cf0'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_5a48b03f3743455dbb4f504cc5fc4cf0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u534e\u4e3a",
#                     "value": 123
#                 },
#                 {
#                     "name": "\u5c0f\u7c73",
#                     "value": 154
#                 },
#                 {
#                     "name": "Oppo",
#                     "value": 109
#                 },
#                 {
#                     "name": "Vivo",
#                     "value": 104
#                 },
#                 {
#                     "name": "\u4e2d\u5174",
#                     "value": 76
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "70%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u534e\u4e3a",
#                 "\u5c0f\u7c73",
#                 "Oppo",
#                 "Vivo",
#                 "\u4e2d\u5174"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u56fd\u4ea7\u624b\u673a\u9500\u91cf\u5bf9\u6bd4",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_5a48b03f3743455dbb4f504cc5fc4cf0.setOption(option_5a48b03f3743455dbb4f504cc5fc4cf0);
#         });
#     </script>

# %% [markdown]
# ## 散点图

# %%
# 1. 准备数据
x = abs(np.random.randn(1000))
y = abs(x + np.random.randn(1000))
# 转换成python原生数组
x_list = x.tolist()
y_list = y.tolist()

# 2. 构建元件
scatter = (
    Scatter()
    .add_xaxis(x_list)
    .add_yaxis('散点图',
               y_list,
               label_opts = opts.LegendOpts(is_show = False)
               )
)

# 3. 渲染输出
scatter.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bb8773c1c34a4a43afddd54924f87b4a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bb8773c1c34a4a43afddd54924f87b4a = echarts.init(
#                     document.getElementById('bb8773c1c34a4a43afddd54924f87b4a'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_bb8773c1c34a4a43afddd54924f87b4a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u6563\u70b9\u56fe",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     0.22905557014616712,
#                     0.065157278261544
#                 ],
#                 [
#                     0.7593248040070626,
#                     1.2174618738337728
#                 ],
#                 [
#                     1.2353941795847108,
#                     3.094435249223699
#                 ],
#                 [
#                     0.13929608285247727,
#                     0.502152067914397
#                 ],
#                 [
#                     0.4115650934158165,
#                     1.6399381311207217
#                 ],
#                 [
#                     1.0941713725738083,
#                     2.002925146799668
#                 ],
#                 [
#                     0.14237920710402255,
#                     0.5049243553858354
#                 ],
#                 [
#                     1.058286246237101,
#                     1.333634885318482
#                 ],
#                 [
#                     0.8324623076567288,
#                     0.9741362017874147
#                 ],
#                 [
#                     0.7240476228038994,
#                     0.7354807530293385
#                 ],
#                 [
#                     1.2490085778737472,
#                     3.468257512350508
#                 ],
#                 [
#                     0.4482283335192519,
#                     0.9947010772141571
#                 ],
#                 [
#                     0.3057140239943824,
#                     0.2384161203873062
#                 ],
#                 [
#                     1.0490159944116373,
#                     0.24329210006180602
#                 ],
#                 [
#                     0.6074154425692031,
#                     1.2582365233154036
#                 ],
#                 [
#                     0.11485137926954256,
#                     1.1793462293955994
#                 ],
#                 [
#                     0.3316228850740892,
#                     1.274378814519594
#                 ],
#                 [
#                     0.07486956803753411,
#                     1.4219956567194956
#                 ],
#                 [
#                     0.0658917566206408,
#                     0.14551455856676226
#                 ],
#                 [
#                     0.31360362205865466,
#                     0.8233770409548528
#                 ],
#                 [
#                     0.4305100095459627,
#                     0.5614462832600675
#                 ],
#                 [
#                     0.648739962473744,
#                     1.779743962934384
#                 ],
#                 [
#                     1.1912670628406834,
#                     0.6016875056153521
#                 ],
#                 [
#                     1.456065077042813,
#                     1.1712937087716395
#                 ],
#                 [
#                     2.1896549754725525,
#                     1.6511350539603837
#                 ],
#                 [
#                     0.1514367427883041,
#                     0.46469614764207934
#                 ],
#                 [
#                     1.0072412947983012,
#                     0.7338485768161158
#                 ],
#                 [
#                     0.6325330733130576,
#                     1.0361691710050434
#                 ],
#                 [
#                     0.6041844407376592,
#                     0.504814242927594
#                 ],
#                 [
#                     1.0115165579805707,
#                     0.10697279287710604
#                 ],
#                 [
#                     1.406418036064363,
#                     2.9881575451322
#                 ],
#                 [
#                     0.8559927581901794,
#                     0.18700268435804235
#                 ],
#                 [
#                     0.8370866399769901,
#                     1.3838110143606408
#                 ],
#                 [
#                     0.08022701114913734,
#                     0.20527863976275362
#                 ],
#                 [
#                     0.3766859134066205,
#                     0.007067257483262757
#                 ],
#                 [
#                     0.22137539833758618,
#                     2.807590145956422
#                 ],
#                 [
#                     1.2254620567994188,
#                     1.308243325318624
#                 ],
#                 [
#                     3.3236997534104864,
#                     2.42917248012158
#                 ],
#                 [
#                     0.029458503858458076,
#                     1.0020228880870126
#                 ],
#                 [
#                     0.1838750855048559,
#                     0.6406780382553697
#                 ],
#                 [
#                     0.297964312075495,
#                     1.0255552694548902
#                 ],
#                 [
#                     0.9491510742427677,
#                     1.2269289243876487
#                 ],
#                 [
#                     0.5066212013227909,
#                     1.6595958975499452
#                 ],
#                 [
#                     1.1118517000377868,
#                     0.9735484904548433
#                 ],
#                 [
#                     1.0056045273600336,
#                     0.5865043841478416
#                 ],
#                 [
#                     0.06088131017201109,
#                     2.256053931705843
#                 ],
#                 [
#                     1.7195435566108495,
#                     0.8093470194077647
#                 ],
#                 [
#                     1.2428790598463462,
#                     1.4734735459987864
#                 ],
#                 [
#                     0.957705252738615,
#                     0.0377895464644149
#                 ],
#                 [
#                     0.601510621285269,
#                     1.6971643959062555
#                 ],
#                 [
#                     0.1642686407635807,
#                     0.5609236075283871
#                 ],
#                 [
#                     0.35096342739528197,
#                     0.7913529564285557
#                 ],
#                 [
#                     0.5130669043417294,
#                     1.9737358619439465
#                 ],
#                 [
#                     0.32978062014721377,
#                     0.20133402894597877
#                 ],
#                 [
#                     0.6030369761929025,
#                     0.41141916460015937
#                 ],
#                 [
#                     0.4708338544538462,
#                     1.808746960534575
#                 ],
#                 [
#                     0.12955307861233778,
#                     0.1181023900778804
#                 ],
#                 [
#                     1.0383889675500615,
#                     2.1180349138715338
#                 ],
#                 [
#                     0.1304427119054208,

# %%
## 使用真实数据集（小费和总金额的关系）
df1 = pd.read_csv('../Pandas/Database/data/tips.csv')
df1.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 1. 准备数据
x = df1.total_bill.tolist()
y = df1.tip.tolist()

# 2. 构建元件，添加元件，设置选项
scatter = (
    Scatter()
    .add_xaxis(x)
    .add_yaxis('',
               y,
               label_opts = opts.LegendOpts(is_show = False)
               )
    .set_global_opts(title_opts = opts.TitleOpts(title = '小费和总金额的关系'),
                     xaxis_opts = opts.AxisOpts(min_ = min(x) - 1, max_ = max(x) + 1))           
)

# 3. 渲染输出
scatter.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a776abba02a04bd497d3345472512e0f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a776abba02a04bd497d3345472512e0f = echarts.init(
#                     document.getElementById('a776abba02a04bd497d3345472512e0f'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_a776abba02a04bd497d3345472512e0f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     16.99,
#                     1.01
#                 ],
#                 [
#                     10.34,
#                     1.66
#                 ],
#                 [
#                     21.01,
#                     3.5
#                 ],
#                 [
#                     23.68,
#                     3.31
#                 ],
#                 [
#                     24.59,
#                     3.61
#                 ],
#                 [
#                     25.29,
#                     4.71
#                 ],
#                 [
#                     8.77,
#                     2.0
#                 ],
#                 [
#                     26.88,
#                     3.12
#                 ],
#                 [
#                     15.04,
#                     1.96
#                 ],
#                 [
#                     14.78,
#                     3.23
#                 ],
#                 [
#                     10.27,
#                     1.71
#                 ],
#                 [
#                     35.26,
#                     5.0
#                 ],
#                 [
#                     15.42,
#                     1.57
#                 ],
#                 [
#                     18.43,
#                     3.0
#                 ],
#                 [
#                     14.83,
#                     3.02
#                 ],
#                 [
#                     21.58,
#                     3.92
#                 ],
#                 [
#                     10.33,
#                     1.67
#                 ],
#                 [
#                     16.29,
#                     3.71
#                 ],
#                 [
#                     16.97,
#                     3.5
#                 ],
#                 [
#                     20.65,
#                     3.35
#                 ],
#                 [
#                     17.92,
#                     4.08
#                 ],
#                 [
#                     20.29,
#                     2.75
#                 ],
#                 [
#                     15.77,
#                     2.23
#                 ],
#                 [
#                     39.42,
#                     7.58
#                 ],
#                 [
#                     19.82,
#                     3.18
#                 ],
#                 [
#                     17.81,
#                     2.34
#                 ],
#                 [
#                     13.37,
#                     2.0
#                 ],
#                 [
#                     12.69,
#                     2.0
#                 ],
#                 [
#                     21.7,
#                     4.3
#                 ],
#                 [
#                     19.65,
#                     3.0
#                 ],
#                 [
#                     9.55,
#                     1.45
#                 ],
#                 [
#                     18.35,
#                     2.5
#                 ],
#                 [
#                     15.06,
#                     3.0
#                 ],
#                 [
#                     20.69,
#                     2.45
#                 ],
#                 [
#                     17.78,
#                     3.27
#                 ],
#                 [
#                     24.06,
#                     3.6
#                 ],
#                 [
#                     16.31,
#                     2.0
#                 ],
#                 [
#                     16.93,
#                     3.07
#                 ],
#                 [
#                     18.69,
#                     2.31
#                 ],
#                 [
#                     31.27,
#                     5.0
#                 ],
#                 [
#                     16.04,
#                     2.24
#                 ],
#                 [
#                     17.46,
#                     2.54
#                 ],
#                 [
#                     13.94,
#                     3.06
#                 ],
#                 [
#                     9.68,
#                     1.32
#                 ],
#                 [
#                     30.4,
#                     5.6
#                 ],
#                 [
#                     18.29,
#                     3.0
#                 ],
#                 [
#                     22.23,
#                     5.0
#                 ],
#                 [
#                     32.4,
#                     6.0
#                 ],
#                 [
#                     28.55,
#                     2.05
#                 ],
#                 [
#                     18.04,
#                     3.0
#                 ],
#                 [
#                     12.54,
#                     2.5
#                 ],
#                 [
#                     10.29,
#                     2.6
#                 ],
#                 [
#                     34.81,
#                     5.2
#                 ],
#                 [
#                     9.94,
#                     1.56
#                 ],
#                 [
#                     25.56,
#                     4.34
#                 ],
#                 [
#                     19.49,
#                     3.51
#                 ],
#                 [
#                     38.01,
#                     3.0
#                 ],
#                 [
#                     26.41,
#                     1.5
#                 ],
#                 [
#                     11.24,
#                     1.76
#                 ],
#                 [
#                     48.27,
#                     6.73
#                 ],
#                 [
#                     20.29,
#                     3.21
#                 ],
#                 [
#                     13.81,
#                     2.0
#                 ],
#                 [
#                     11.02,
#                     1.98
#                 ],
#                 [
#                     18.29,
#                     3.76
#                 ],
#                 [
#                     17.59,
#                     2.64
#                 ],
#                 [
#                     20.08,
#                     3.15
#                 ],
#                 [
#                     16.45,
#                     2.47
#                 ],
#                 [
#                     3.07,
#                     1.0
#                 ],
#                 [
#                     20.23,
#                     2.01
#                 ],
#                 [
#                     15.01,
#                     2.09
#                 ],
#                 [
#                     12.02,
#                     1.97
#                 ],
#                 [
#                     17.07,
#                     3.0
#                 ],
#                 [
#                     26.86,
#                     3.14
#                 ],
#                 [
#                     25.28,
#                     5.0
#                 ],
#                 [
#                     14.73,
#                     2.2
#                 ],
#                 [
#                     10.51,
#                     1.25
#                 ],
#                 [
#                     17.92,
#                     3.08
#                 ],

# %% [markdown]
# ## 层叠图形

# %%
# 1. 准备数据
x = ['华为','小米','Oppo','Vivo','中兴']
y_bar = [123,154,109,104,76]
y_line = [12,38,27,20,15]

# 2. 构架元件，分开构建
bar = (
    Bar()
    .add_xaxis(x)
    .add_yaxis('销售额',
               y_bar,
               itemstyle_opts = opts.ItemStyleOpts(color = 'rgba(154, 150, 255, 0.5)')
    )
)

line = (
    Line()
    .add_xaxis(x)
    .add_yaxis('利润', y_line)
)

# 3. 渲染输出
# 依次渲染会出现覆盖现象
# 使用overlap
overlap = line.overlap(bar)
overlap.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7508918152524be3a57c3f5faeba4dd9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7508918152524be3a57c3f5faeba4dd9 = echarts.init(
#                     document.getElementById('7508918152524be3a57c3f5faeba4dd9'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_7508918152524be3a57c3f5faeba4dd9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5229\u6da6",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "\u534e\u4e3a",
#                     12
#                 ],
#                 [
#                     "\u5c0f\u7c73",
#                     38
#                 ],
#                 [
#                     "Oppo",
#                     27
#                 ],
#                 [
#                     "Vivo",
#                     20
#                 ],
#                 [
#                     "\u4e2d\u5174",
#                     15
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "bar",
#             "name": "\u9500\u552e\u989d",
#             "legendHoverLink": true,
#             "data": [
#                 123,
#                 154,
#                 109,
#                 104,
#                 76
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "itemStyle": {
#                 "color": "rgba(154, 150, 255, 0.5)"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5229\u6da6",
#                 "\u9500\u552e\u989d"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "\u534e\u4e3a",
#                 "\u5c0f\u7c73",
#                 "Oppo",
#                 "Vivo",
#                 "\u4e2d\u5174"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0
#         }
#     ]
# };
#                 chart_7508918152524be3a57c3f5faeba4dd9.setOption(option_7508918152524be3a57c3f5faeba4dd9);
#         });
#     </script>

# %% [markdown]
# ## 地图(代码示例，加载不出)

# %%
# # 1. 准备数据
# area = ['北京','上海','广州','深圳','四川','湖北','山东','河南']
# data = [(i, np.random.randint(100,2000)) for i in area]
# print(data)

# # 2. 构建元件
# geo = (
#     Geo()
#     .add_schema(maptype = 'china') #设置地图的基准
#     .add('',data)
#     .set_series_opts(label_opts = opts.LabelOpts(is_show = False)) #是否显示地理信息
#     .set_global_opts(
#         visualmap_opts = opts.VisualMapOpts(),
#         title_opts = opts.TitleOpts(title = '2025年各地gdp', pos_left = 'center')
#     )
# )

# # 3. 渲染输出
# geo.load_javascript()
# geo.render_notebook()

# %% [markdown]
# ## 词云图(这个文件也加载不出来)

# %%
dfw = pd.read_csv('data/welfare.csv')
dfw.head()
# Out:
#    Unnamed: 0       0     1
# 0           0    五险一金  6806
# 1           1  补充医疗保险  1268
# 2           2   补充公积金   596
# 3           3    弹性工作  2818
# 4           4    交通补贴  1646

# %%
dfw.drop('Unnamed: 0', axis = 1, inplace = True)
dfw.head()
# Out:
#         0     1
# 0    五险一金  6806
# 1  补充医疗保险  1268
# 2   补充公积金   596
# 3    弹性工作  2818
# 4    交通补贴  1646

# %%
list(dfw)
#不能直接转换成列表
# Out:
# ['0', '1']

# %%
listWS = np.array(dfw).tolist()

# %%
listWS[:10]
# Out:
# [['五险一金', 6806],
#  ['补充医疗保险', 1268],
#  ['补充公积金', 596],
#  ['弹性工作', 2818],
#  ['交通补贴', 1646],
#  ['餐饮补贴', 2691],
#  ['年终奖金', 4163],
#  ['绩效奖金', 4950],
#  ['定期体检', 2908],
#  ['员工旅游', 3454]]

# %%
# 词云图
# c = (
#     WordCloud()
#     .add('', listWS, word_size_range=[20,100])
# )
# c.render_notebook()

# %% [markdown]
# ## 矩形树图

# %%
# 1.准备数据
# 形式是：[{'value':值,'name':项}]，列表中的字典
tree_data = [
    {'value':50000,'name':'SEM'},
    {'value':8900,'name':'EC'},
    {'value':6700,'name':'QQ群'},
    {'value':3200,'name':'百度'},
    {'value':2100,'name':'搜狗'},
    {'value':800,'name':'淘宝'},
    {'value':500,'name':'京东'}    
]

# 2.构建元件
q = (
    TreeMap()
    .add('消费数据', tree_data)
)

q.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3032afd3208a45108a41262bbdcc94e4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3032afd3208a45108a41262bbdcc94e4 = echarts.init(
#                     document.getElementById('3032afd3208a45108a41262bbdcc94e4'), 'white', {renderer: 'canvas', locale: 'ZH'});
#                 var option_3032afd3208a45108a41262bbdcc94e4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "treemap",
#             "name": "\u6d88\u8d39\u6570\u636e",
#             "data": [
#                 {
#                     "value": 50000,
#                     "name": "SEM"
#                 },
#                 {
#                     "value": 8900,
#                     "name": "EC"
#                 },
#                 {
#                     "value": 6700,
#                     "name": "QQ\u7fa4"
#                 },
#                 {
#                     "value": 3200,
#                     "name": "\u767e\u5ea6"
#                 },
#                 {
#                     "value": 2100,
#                     "name": "\u641c\u72d7"
#                 },
#                 {
#                     "value": 800,
#                     "name": "\u6dd8\u5b9d"
#                 },
#                 {
#                     "value": 500,
#                     "name": "\u4eac\u4e1c"
#                 }
#             ],
#             "width": "80%",
#             "height": "80%",
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "upperLabel": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "drillDownIcon": "\u25b6",
#             "roam": true,
#             "nodeClick": "zoomToNode",
#             "zoomToNodeRatio": 0.1024,
#             "colorMappingBy": "index",
#             "visibleMin": 10
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6d88\u8d39\u6570\u636e"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     }
# };
#                 chart_3032afd3208a45108a41262bbdcc94e4.setOption(option_3032afd3208a45108a41262bbdcc94e4);
#         });
#     </script>
