# %% [markdown]
# # Chapter-01. 计算机视觉概述

# %% [markdown]
# ## 【章节目标】
# - 了解计算机视概念
# - 了解计算机视觉任务和应用
# - 了解计算机视觉难点
#
# ## 【章节内容】
# ### 1.1 计算机视觉概念
# #### 1.1.1 概念介绍
# **计算机视觉概念**
# - 计算机视觉（Computer Vision）是人工智能的一个重要分支，它要解决的问题就是：看懂图像里的内容。比如：
# - 图片里的宠物是猫还是狗？
# - 图片里的人是老张还是老王？
# - 这张照片里，桌子上放了哪些物品？
#
# ![image.png](attachment:image.png)
#
# **为什么研究计算机视觉**
#
# 使机器具有感知能力
#
# ![image-2.png](attachment:image-2.png)
#
# 人类视觉 计算机视觉
#
# - 每时每刻海量图像数据
# - 人的大脑皮层， 有差不多 70% 都是在处理视觉信息。 是人类获取信息最主要的渠道，没有之一。
# - 在网络世界，照片和视频（图像的集合）也正在发生爆炸式的增长
#
# ![image-3.png](attachment:image-3.png)
# >网络上新增数据的占比趋势图。灰色是结构化数据，蓝色是非结构化数据（大部分都是图像和视频）。可以很明显的发现，图片和视频正在以指数级的速度在增长。
#
# - 必须看懂图片！
# - 在计算机视觉出现之前，图像对于计算机来说是黑盒的状态。
# - 一张图片对于机器只是一个文件。机器并不知道图片里的内容到底是什么，只知道这张图片是什么尺寸，多少MB，什么格式的。
#
# ![image-4.png](attachment:image-4.png)
# >文件名：IMG_20200102
#     图片尺寸：3456X4036
#     图片大小：3.57MB
#     图片格式：JPG
#     CV之前，计算机智能看到文件属性，看不懂图片内容，如果计算机、人工智能想要在现实世界发挥重要作用，就必须看懂图片！这就是计算机视觉要解决的问题。

# %% [markdown]
# #### 1.1.2 相关学科
# 计算机视觉、数字图像处理和计算机图形学的区别
#
# - 数字图象处理：图像→图像，例如：photoshop
# - 计算机视觉：图像→各种特征
# - 计算机图形学：各种特征→图像，例如：3dmax
#
# **数字图像处理**
#
# 数字图像处理输入的是数字图像经过相关的降噪，增强，色彩处理等，会输出图像，一般的可以调节亮度，对比度等
#
# ![image.png](attachment:image.png)
#
# **计算机视觉**
#
# 计算机视觉的输入一般可以是图像或视频数据，甚至是视觉数据量化信息（如特征），经过一系列的图像和视频算法处理后，可以获得量化的数据输出（如大小，距离，颜色，数量等）
#
#
# ![image-2.png](attachment:image-2.png)
#
# **计算机图形学**
#
# 计算机图形学(Computer Graphics，简称CG)是一种使用数学算法将二维或三维图形转化为计算机显示器的栅格形式的科学。狭义地理解，计算机图形学是数字图象处理或计算机视觉的逆过程。
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### 1.1.3 计算机视觉发展史
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.2 计算机视觉任务和应用
# #### 1.2.1 主要任务
# **计算机视觉主要任务**
#
# - 图像分类
# - 物体定位
# - 目标检测
# - 语义分割
# - 实例分割
# - 关键点检测
# - 行为识别
# - 目标跟踪
# - 视频分类
# - 超分辨率
# - 图像理解
# - 图像生成
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.3 计算机视觉面临的困难
# #### 1.3.1 计算机视觉面临的困难
# 计算机视觉面临的困难
#
# - 图像多义性：三维场景被投影为二维图像，深度和不可见部分的信息被丢失，因而会出现不同形状的三维物体投影在图像平面上产生相同图像的问题. 另外，在不同角度获取同一物体的图像会有很大的差异.
# - 环境因素影响∶ 场景中的诸多因素，包括照明、物体形状、表面颜色、摄像机以及空间关系变化都会对成像有影响，
# - 知识导引∶ 同样的图像在不同的知识导引下，将会产生不同的识别结果..
# - 大量数据∶ 灰度图像，彩色图像，深度图像的信息量十分巨大，巨大的数据量需要很大的存贮空间，同时不易实现快速处理.
#
# **图像深度影响**
#
# ![image.png](attachment:image.png)
#
# **环境因素影响**
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# **知识导引**
#
# ![image-6.png](attachment:image-6.png)
#
# 遮挡（Occlusion）
#
# ![image-7.png](attachment:image-7.png)
